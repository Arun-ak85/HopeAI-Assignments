# %%
class SubfieldsInAI():
    def Subfields():
        print("Sub-fields in AI are:")
        print("Machine Learning")
        print("Neural Networks")
        print("Neural Networks")
        print("Vision")
        print("Robotics")
        print("Speech Processing")
        print("Natural Language Processing")

# %%
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
class OddEven():
    def OddEven():
        num=int(input("Enter the number"))
        if((num%2 ==0)):
            print("even number")
        else:
            print("Odd number")

# %%
OddEven.OddEven()
# Out:
# Enter the number 34
# even number

# %%
class ElegiblityForMarriage():
    def Elegible():
        name=(input("Your Gender Male/Female"))[:6]
        age=int(input("Your Age"))
        if(age>=21 and name =="Male"):
            print("ELIGIBLE")
        elif(age>=18 and name =="Female"):
            print("ELIGIBLE")
        else:
            print("NOT ELIGIBLE")

# %%
ElegiblityForMarriage.Elegible()
# Out:
# Your Gender Male/Female femaleeeeeeee
# Your Age 43
# NOT ELIGIBLE

# %%
class FindPercent():
    def percentage():
        subject1=float(input("subject1"))
        subject2=float(input("subject2"))
        subject3=float(input("subject3"))
        subject4=float(input("subject4"))
        subject5=float(input("subject5"))
        total = subject1+subject2+subject3+subject4+subject5
        print("Total",total)
        Avg= total/5
        print("Avg",Avg)

# %%
FindPercent.percentage()
# Out:
# subject1 94
# subject2 98
# subject3 87
# subject4 89
# subject5 78
# Total 446.0
# Avg 89.2

# %%
class triangle():
  def triangle():
      Height=float(input("Height"))
      Breadth=float(input("Breadth"))
      print("Area formula: (Height*Breadth)/2")
      Area=(Height*Breadth)/2
      print("Area of Triangle",Area)
      Height1=float(input("Height1"))
      Height2=float(input("Height1"))
      Breadth=float(input("Breadth"))
      print("Perimeter formula: Height1+Height2+Breadth")
      perimeter=Height1+Height2+Breadth
      print("Perimeter of Triangle:",perimeter)

# %%
triangle.triangle()
# Out:
# Height 12
# Breadth 14
# Area formula: (Height*Breadth)/2
# Area of Triangle 84.0
# Height1 4
# Height1 56.7
# Breadth 5.7
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10 66.4
