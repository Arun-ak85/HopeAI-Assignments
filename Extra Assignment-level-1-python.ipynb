# %%
print("HOPE AI");
# Out:
# HOPE AI

# %%
mytext=(input("Enter your institute name?"))
# Out:
# Enter your institute name? HOPE AI

# %%
myname=(input("Enter your name:"))
myage=int(input("Enter your age:"))
myname=(input("Enter your school name:"))
myname=(input("Enter your drgree:"))
# Out:
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your drgree: B.E CSE

# %%
    a=int(input("Enter the first number"))
    print("a=", a);
    b=int(input("Enter the second number"))
    print("b= ", b);
    add=a+b;
    print("Sum=",add);
# Out:
# Enter the first number 43
# a= 43
# Enter the second number 34
# b=  34
# Sum= 77

# %%
    a=int(input("Enter the first number"))
    print("a=", a);
    b=int(input("Enter the second number"))
    print("b= ", b);
    add=a-b;
    print("Sub=",add);
# Out:
# Enter the first number 43
# a= 43
# Enter the second number 34
# b=  34
# Sub= 9

# %%
    a=int(input("Enter the first number"))
    print("a=", a);
    b=int(input("Enter the second number"))
    print("b= ", b);
    mul=a*b;
    print("mul=",mul);
# Out:
# Enter the first number 63
# a= 63
# Enter the second number 97
# b=  97
# mul= 6111

# %%
    a=float(input("Enter the first number"))
    print("a=", a);
    b=float(input("Enter the second number"))
    print("b= ", b);
    div=a/b;
    print("float=",div);
# Out:
# Enter the first number 45
# a= 45
# Enter the second number 7
# b=  7
# mul= 6.428571428571429

# %%
    import math 
    a=int(input("Enter the first number"))
    print("a=", a);
    b=int(input("Enter the second number"))
    print("b= ", b);
    div=a/b;
    result = math.floor(a/b)
    print("floor divison=",result);
# Out:
# Enter the first number 76
# a= 76
# Enter the second number 31
# b=  31
# floor divison= 2

# %%
a = 76
b = 31
result = a % b
print(result)
# Out:
# 14

# %%
a = 4
b = 4
power_result = pow(a, b)
print(f"{a} raised to the power of {b} is: {power_result}")
# Out:
# 4 raised to the power of 4 is: 256
